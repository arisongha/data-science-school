# %%
# %matplotlib inline

# %%
N = 30
mu = [0.1, 0.1, 0.1, 0.1, 0.3, 0.3]
rv = sp.stats.multinomial(N, mu)

# %%
np.random.seed(0)
x = rv.rvs(100)
x[:5]
# Out:
# array([[ 3,  4,  3,  3,  8,  9],
#        [ 3,  3,  5,  6,  6,  7],
#        [ 4,  3,  3,  5,  5, 10],
#        [ 1,  0,  5,  5, 12,  7],
#        [ 7,  4,  2,  3,  5,  9]])

# %%
plt.boxplot(x)
plt.title("result of multinomialDistribution")
plt.xlabel("class")
plt.ylabel("binomial")
plt.show()

# %%
df = pd.DataFrame(x).stack().reset_index()
df.columns = ["trial", "class", "binomial"]

# %%
sns.boxplot(x="class", y="binomial", data=df)
sns.stripplot(x="class", y="binomial", data=df, jitter=True, color=".3")
plt.title("result of simulation")
plt.show()
