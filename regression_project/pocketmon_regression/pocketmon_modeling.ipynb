# %%
import numpy as np
import pandas as pd
import warnings
warnings.simplefilter('ignore')
import seaborn as sns
import scipy as sp
import scipy.stats
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Pokemon with stats

# %% [markdown]
# ### `회귀분석을 통해 Attack 값 예측하기!`

# %% [markdown]
# # EDA START

# %% [markdown]
# ## 1. 데이터의 도메인지식 파악하기

# %% [markdown]
# - #: ID for each pokemon
# - Name: Name of each pokemon
# - Type 1: Each pokemon has a type, this determines weakness/resistance to attacks
# - Type 2: Some pokemon are dual type and have 2
# - Total: sum of all stats that come after this, a general guide to how strong a pokemon is
# - HP: hit points, or health, defines how much damage a pokemon can withstand before fainting
# - Attack: the base modifier for normal attacks (eg. Scratch, Punch)
# - Defense: the base damage resistance against normal attacks
# - SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# - SP Def: the base damage resistance against special attacks
# - Speed: determines which pokemon attacks first each round

# %% [markdown]
# - #: 각 포켓몬의 ID
# - 이름 : 각 포켓몬의 이름
# - 유형 1 : 각 포켓몬은 유형이 있습니다. 이것은 약점 / 공격에 대한 저항력을 결정합니다.
# - 유형 2 : 일부 포켓몬은 듀얼 유형이며 2 개가 있습니다.
# - 총계 : 이것 후에 오는 모든 통계의 합, 포켓몬이 얼마나 강한 지에 대한 일반적인 지침
# - HP : 체력이나 체력으로 포켓몬이 실신하기 전에 얼마나 많은 피해를 입을 지 결정합니다.
# - 어택 (Attack) : 일반 공격 (예 : 스크래치, 펀치)의 기본 수정 자.
# - 방어 : 정상적인 공격에 대한 기본 피해 저항
# - SP 공격 : 특수 공격, 특수 공격을위한 기본 수정 기호 (예 : 화재 폭발, 기포 빔)
# - SP Def : 특수 공격에 대한 기본 데미지 저항
# - 속도 : 매 라운드마다 어느 포켓몬을 공격할지 결정합니다.

# %%
pm_data = pd.read_csv('./Pokemon.csv', encoding='utf-8')

# %%
pm_data.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# ### 1.1. 데이터 개수, 타입 확인

# %%
pm_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# ### 1.2. 각 데이터 개별 파악

# %% [markdown]
# > #### 1.2.1. #(아이디) : int

# %%
pm_data[pm_data['#'] == 6]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %% [markdown]
# - **'#' 아이디의 경우 한 종류에서 진화된 포켓몬은 같은 아이디를 가지고 있음을 알 수 있다.**

# %% [markdown]
# - 같은 아이디를 가지고 있는 데이터들이 어떠한 영향을 미치는지 확인할 필요 있다.

# %% [markdown]
# - 같은 아이디를 가지는 데이터들을 표시하기 위한 Evol 컬럼을 만들어주었다.

# %%
idx_id = pm_data.groupby("#")["#"].count() > 1

# %%
id_index = list((idx_id[idx_id == True]).index)

# %%
pm_data['Evol'] = False

# %%
pm_data.loc[2,"#"]
# Out:
# 3

# %%
for i in range(len(pm_data)):
    if pm_data.loc[i,"#"] in id_index:
        pm_data.loc[i,'Evol'] = True
    else :
        pm_data.loc[i,'Evol'] = False

# %%
pm_data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Evol
# 0       65       65     45           1      False  False
# 1       80       80     60           1      False  False
# 2      100      100     80           1      False   True
# 3      122      120     80           1      False   True
# 4       60       50     65           1      False  False
# 5       80       65     80           1      False  False
# 6      109       85    100           1      False   True
# 7      130       85    100           1      False   True
# 8      159      115    100           1      False   True
# 9       50       64     43           1      False  False

# %% [markdown]
# > #### 1.2.2. Name(포켓몬이름) : object

# %%
pm_name = pm_data.groupby("Name").apply(lambda x: x["Name"].unique()[0])
len(pm_data) == len(pm_name) #전체데이터 수와 name의 unique()적용한게 같다.
# Out:
# True

# %% [markdown]
# - Evol이 'True'인 값, 즉 '#' 값이 같은 것들은 Name 컬럼의 값이 일부분 중복된다.

# %% [markdown]
# - **Name_evol : **진화한 포켓몬의 경우 1,2,3 형태로 진화의 정도를 표시해 준다.

# %%
import math

# %%
def cal_evol_seq(dataFrame):
    for index, data in enumerate(dataFrame['#']):
        if index == 0:
            dataFrame.loc[index,"Name_evol"] = int(math.floor(0))
        else :
            if dataFrame.loc[index,'Evol'] == True:
                if data == dataFrame.loc[index-1,'#']:
                    if dataFrame.loc[index-1,'Name_evol'] == 1:
                        dataFrame.loc[index,"Name_evol"] = int(math.floor(2))
                    elif dataFrame.loc[index-1,'Name_evol'] == 2:
                        dataFrame.loc[index,"Name_evol"] = int(math.floor(3))
                    else:
                        dataFrame.loc[index,"Name_evol"] = int(math.floor(1))
                else:
                    dataFrame.loc[index,"Name_evol"] = int(math.floor(1))
            else:
                dataFrame.loc[index,"Name_evol"] = int(math.floor(0))

# %%
cal_evol_seq(pm_data)

# %%
pm_data.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# 11   9                  Blastoise  Water     NaN    530  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                   Caterpie    Bug     NaN    195  45      30       35
# 14  11                    Metapod    Bug     NaN    205  50      20       55
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# 16  13                     Weedle    Bug  Poison    195  40      35       30
# 17  14                     Kakuna    Bug  Poison    205  45      25       50
# 18  15                   Beedrill    Bug  Poison    395  65      90       40
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary   Evol  Name_evol
# 0        65       65     45           1      False  False        0.0
# 1        80       80     60           1      False  False        0.0
# 2       100      100     80           1      False   True        1.0
# 3       122      120     80           1      False   True        2.0
# 4        60       50     65           1      False  False        0.0
# 5        80       65     80           1      False  False        0.0
# 6       109       85    100           1      False   True        1.0
# 7       130       85    100           1      False   True        2.0
# 8       159      115    100           1      False   True        3.0
# 9        50       64     43           1      False  False        0.0
# 10       65       80     58           1      False  False        0.0
# 11       85      105     78           1      False   True        1.0
# 12      135      115     78           1      False   True        2.0
# 13       20       20     45           1      False  False        0.0
# 14       25       25     30           1      False  False        0.0
# 15       90       80     70           1      False  False        0.0
# 16       20       20     50           1      False  False        0.0
# 17       25       25     35           1      False  False        0.0
# 18       45       80     75           1      False   True        1.0
# 19       15       80    145           1      False   True        2.0

# %% [markdown]
# > #### 1.2.3. Type 1(포켓몬유형) : object

# %%
pm_type1 = pm_data.groupby("Type 1").apply(lambda x: x["Type 1"].unique()[0])
len(pm_type1)
# Out:
# 18

# %% [markdown]
# - 유형은 18가지가 있음을 알수있다.

# %%
pm_data.groupby("Type 1")["Type 1"].count()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Type 1, dtype: int64

# %% [markdown]
# - 유형의 카테고리를 확인해보기

# %%
pm_data['Type 1'].str.isnumeric().value_counts()
# Out:
# False    800
# Name: Type 1, dtype: int64

# %% [markdown]
# - numeric 값은 없음을 확인할 수 있다.

# %% [markdown]
# > #### 1.2.4. Type 2(포켓몬유형2) : object

# %% [markdown]
# - Type 2의 경우 다른 feature 들과 달리 800개가 아니라 414개의 데이터가 non-null임을 확인할 수 있다.

# %%
pm_data["Type 2"].isnull().head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9     True
# Name: Type 2, dtype: bool

# %%
pm_data["Type 2"].iloc[4]
# Out:
# nan

# %% [markdown]
# - null 데이터는 NaN 값임을 알 수 있다.

# %%
pm_type2 = pm_data.groupby("Type 2").apply(lambda x: x["Type 2"].unique()[0])
len(pm_type2)
# Out:
# 18

# %%
pm_data.groupby("Type 2")["Type 2"].count()
# Out:
# Type 2
# Bug          3
# Dark        20
# Dragon      18
# Electric     6
# Fairy       23
# Fighting    26
# Fire        12
# Flying      97
# Ghost       14
# Grass       25
# Ground      35
# Ice         14
# Normal       4
# Poison      34
# Psychic     33
# Rock        14
# Steel       22
# Water       14
# Name: Type 2, dtype: int64

# %% [markdown]
# - 속성 값의 Category 자체는 Type 1과 다르지 않으며 Type 1과 Type 2를 모두 가지고 있을 경우 듀얼 속성을 가지고 있다고 할 수 있다.

# %%
pm_data['Type 2'].str.isnumeric().value_counts()
# Out:
# False    414
# Name: Type 2, dtype: int64

# %% [markdown]
# - numeric 값은 없음을 확인할 수 있다.

# %% [markdown]
# > #### 1.2.5. Total(총계) : int

# %% [markdown]
# - Total 값이 어디에 근거한 값인지 확인해보자.
#
#     + Total의 어감상 다른 수치(int) 데이터의 합계는 아닌지 확인해볼 필요가 있다.

# %%
total_bool = pm_data['Total'] ==  pm_data['HP'] + pm_data['Attack'] + pm_data['Defense'] + pm_data['Sp. Atk'] + pm_data['Sp. Def'] + pm_data['Speed']

# %%
for i in total_bool :
    if i != True :
        print('False')

# %% [markdown]
# - Total 값이 다른 수치데이터의 합계라는 것을 파악하였다.
# - **Total 이 존재시 Attack 값은 자동적으로 계산되므로 이 회귀분석 모델에서 Total값을 제외하기로 한다.**

# %%
pm_data['Total'].mean()
# Out:
# 435.1025

# %%
pm_data['Total'].max()
# Out:
# 780

# %%
pm_data['Total'].min()
# Out:
# 180

# %% [markdown]
# - 위의 값은 아래 수치데이터에서도 계속 확인할 것이므로 함수화 해놓는다.

# %%
def stat(column):
    print("[" + column + "] 평균:{}, 최대:{}, 최소:{}".format(pm_data[column].mean(), pm_data[column].max(),  pm_data[column].min()))

# %%
stat('Total')
# Out:
# [Total] 평균:435.1025, 최대:780, 최소:180

# %% [markdown]
# > #### 1.2.6. HP(체력) : int

# %%
stat('HP')
# Out:
# [HP] 평균:69.25875, 최대:255, 최소:1

# %% [markdown]
# - 최소 값이 '1' 인것이 조금 의아해서 HP 30미만의 데이터의 비율을 파악해보았다. 마찬가지로 아래에서 계속 사용할 것이므로 함수화 하였다.

# %%
def percentage(column, limit):
    print(len(pm_data[pm_data[column] < limit]) / len(pm_data) * 100)

# %%
percentage('HP', 30)
# Out:
# 1.375

# %%
pm_data[pm_data['HP'] < 5]
# Out:
#        #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 316  292  Shedinja    Bug  Ghost    236   1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary   Evol  Name_evol
# 316       30     40           3      False  False        0.0

# %% [markdown]
# - **HP 30 미만의 데이터가 1.38% 밖에 되지 않았다.**

# %% [markdown]
# > #### 1.2.7. Attack(체력) : int

# %%
stat('Attack')
# Out:
# [Attack] 평균:79.00125, 최대:190, 최소:5

# %%
percentage('Attack', 20)
# Out:
# 0.75

# %% [markdown]
# - **Attack 20 미만의 데이터가 0.75% 밖에 되지 않았다.**

# %% [markdown]
# > #### 1.2.8. Defense(방어) : int

# %%
stat('Defense')
# Out:
# [Defense] 평균:73.8425, 최대:230, 최소:5

# %%
percentage('Defense', 20)
# Out:
# 0.8750000000000001

# %% [markdown]
# - **Defense 20 미만의 데이터가 0.88% 밖에 되지 않았다.**

# %% [markdown]
# > #### 1.2.9. Sp. Atk(특수공격) : int

# %%
stat('Sp. Atk')
# Out:
# [Sp. Atk] 평균:72.82, 최대:194, 최소:10

# %%
percentage('Sp. Atk', 20)
# Out:
# 0.8750000000000001

# %% [markdown]
# - **Sp. Atk 20 미만의 데이터가 0.88% 밖에 되지 않았다.**

# %% [markdown]
# > #### 1.2.10. Sp. Def(특수공격방어) : int

# %%
stat('Sp. Def')
# Out:
# [Sp. Def] 평균:71.9025, 최대:230, 최소:20

# %%
percentage('Sp. Def', 30)
# Out:
# 2.25

# %% [markdown]
# - **Sp. Def 30 미만의 데이터가 2.25% 밖에 되지 않았다.**

# %% [markdown]
# > #### 1.2.11. Speed(속도) : int

# %%
stat('Speed')
# Out:
# [Speed] 평균:68.2775, 최대:180, 최소:5

# %%
percentage('Speed', 20)
# Out:
# 1.7500000000000002

# %% [markdown]
# > #### 1.2.12. DualType(듀얼속성) : Object

# %% [markdown]
# - 듀얼속성(Type1, Type2)의 관계에 대해서 파악해보기

# %%
pm_onetype = pm_data[pm_data['Type 2'].isnull()]
pm_onetype.index
# Out:
# Int64Index([  4,   5,   9,  10,  11,  12,  13,  14,  24,  25,
#             ...
#             755, 762, 763, 770, 774, 775, 776, 788, 789, 792],
#            dtype='int64', length=386)

# %%
pm_dualtype_index = (pm_data.index).difference(pm_onetype.index)

# %%
pm_dualtype = pm_data.iloc[pm_dualtype_index, :]
pm_dualtype.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Evol  Name_evol
# 0       65       65     45           1      False  False        0.0
# 1       80       80     60           1      False  False        0.0
# 2      100      100     80           1      False   True        1.0
# 3      122      120     80           1      False   True        2.0
# 6      109       85    100           1      False   True        1.0

# %%
pm_data['Type 2'].fillna(pm_data['Type 1'], inplace=True)

# %%
pm_data['Type 2'] = pm_data['Type 2'].astype(str)

# %%
pm_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 15 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        800 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# Evol          800 non-null bool
# Name_evol     800 non-null float64
# dtypes: bool(2), float64(1), int64(9), object(3)
# memory usage: 82.9+ KB

# %%
pm_data['Dual'] = True

# %%
for i in pm_data['Type 2']:
    if i == "missing" :
        pm_data['Dual'] == False
    else :
        pm_data['Dual'] == True

# %%
pm_data['Dual'] = pm_data[pm_data['Type 1'] == pm_data['Type 2']]['Dual'].replace(True,False)

# %%
pm_data['Dual'].fillna(True, inplace=True)

# %%
pm_data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire    Fire    309  39      52       43
# 5  5                 Charmeleon   Fire    Fire    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water   Water    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Evol  Name_evol   Dual
# 0       65       65     45           1      False  False        0.0   True
# 1       80       80     60           1      False  False        0.0   True
# 2      100      100     80           1      False   True        1.0   True
# 3      122      120     80           1      False   True        2.0   True
# 4       60       50     65           1      False  False        0.0  False
# 5       80       65     80           1      False  False        0.0  False
# 6      109       85    100           1      False   True        1.0   True
# 7      130       85    100           1      False   True        2.0   True
# 8      159      115    100           1      False   True        3.0   True
# 9       50       64     43           1      False  False        0.0  False

# %% [markdown]
# > #### 1.2.13. Generation(세대) : int -> category

# %%
stat('Generation')
# Out:
# [Generation] 평균:3.32375, 최대:6, 최소:1

# %% [markdown]
# > #### 1.2.14. Legendary(전설적포켓몬) : bool

# %% [markdown]
# - 모든 포켓몬의 Total 평균

# %%
pm_data["Total"].mean()
# Out:
# 435.1025

# %% [markdown]
# - Legendary가 아닌 포켓몬의 Total 평균

# %%
pm_data[pm_data["Legendary"] == False]["Total"].mean()
# Out:
# 417.21360544217686

# %% [markdown]
# - Legendary 포켓몬의 Total 평균

# %%
pm_data[pm_data["Legendary"] == True]["Total"].mean()
# Out:
# 637.3846153846154

# %% [markdown]
# - **Legendary 포켓몬의 경우 Total의 수치가 다른 포켓몬의 평균보다 월등히 높음을 알 수 있다.**

# %% [markdown]
# - Legendary 포켓몬의 경우 듀얼속성도 많이 가지는지 확인해보고 싶다.

# %%
pm_leg = pm_data[pm_data["Legendary"] == True]
len(pm_leg.index)
# Out:
# 65

# %%
len(pm_leg[pm_leg['Type 2']=="missing"])
# Out:
# 0

# %% [markdown]
# - **Legendary 포켓몬의 경우 Dual 속성을 가지는 포켓몬이 그렇지 않은 경우보다 더 많았다.**

# %% [markdown]
# ### 1.3. null 데이터 확인

# %%
pm_data.isnull().any()
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# Total         False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# Evol          False
# Name_evol     False
# Dual          False
# dtype: bool

# %% [markdown]
# - Type 2의 경우 듀얼 속성을 가지는 경우에만 값을 가진다. 위에서 확인한바 있다.

# %% [markdown]
# ## 2. 컬럼들간의 관계 파악하기

# %%
# %matplotlib inline
cols = ["Total","HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]
sns.pairplot(pm_data[cols])
plt.show()

# %% [markdown]
# - 대부분의 수치데이터가 Total과 양의 상관관계를 가지고 있음을 파악할 수 있다.

# %%
corr = pm_data.corr()
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr, annot=True, linewidths=.5, fmt='.1f', ax=ax)
plt.show()

# %%
# '-limit >= 상관계수 or limit <= 상관계수' 인 관계 추출 함수
def extract_corr(matrix_corr, limit):
    li_corr = [[row, col, matrix_corr.loc[row, col]]
                 for i, row in enumerate(matrix_corr.columns[:-2]) 
                 for col in matrix_corr.columns[i+1:-1] 
                 if np.abs(matrix_corr.loc[row, col]) >= limit]
    df_corr = pd.DataFrame(li_corr, columns=["Feature1", "Feature2", "corr"])
    df_corr.sort_values(by="corr", ascending=False, inplace=True)
    df_corr.reset_index(drop=True, inplace=True)
    return df_corr

# %%
df_corr = extract_corr(corr, 0.6)
df_corr
# Out:
#   Feature1    Feature2      corr
# 0        #  Generation  0.982516
# 1     Evol   Name_evol  0.920949
# 2    Total     Sp. Atk  0.747250
# 3    Total      Attack  0.736211
# 4    Total     Sp. Def  0.717609
# 5    Total          HP  0.618748
# 6    Total     Defense  0.612787

# %% [markdown]
# - Total은 다른 수치 feature들의 합계이므로 양의 상관관계가 있는 것이 이해되지만 #(아이디)와 Generation의 경우 0.98의 높은 corr가 나온다는 것이 이해되지 않는다.

# %% [markdown]
# - 두 데이터만 따로 확인해 보겠다.

# %%
sns.jointplot(x="#", y="Generation", data=pm_data, height=7, ratio=3, color='blue')
plt.show()

# %% [markdown]
# - **그래프를 통해서 1세대에 약 100~200종류의 포켓몬이 새로 추가되었음을 알 수 있으며, 새로 추가되는 순서대로 #(아이디) 값이 늘어나므로 위와같은 corr 수치가 나왔음을 추측해볼 수 있다.**

# %% [markdown]
# ### VIF

# %% [markdown]
# - 다중공산성을 확인하기 위하여 VIF 를 확인해보았다.

# %% [markdown]
# - 컬럼명 변경은 아래부분에서 해주고있지만 VIF를 위해 여기서 먼저 해주겠다.

# %%
pm_data = pm_data.rename(columns={'#': 'Id', 'Type 1': 'Type1', 'Type 2': 'Type2', 'Sp. Atk': 'Spatk', 'Sp. Def': 'Spdef'})

# %%
from patsy import dmatrix
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
formula = "scale(Id) + scale(HP) + scale(Defense) + scale(Spatk) + scale(Spdef) + scale(Speed) + scale(Generation) + 0"
dfX = dmatrix(formula, pm_data, return_type="dataframe")

# %%
vif = pd.DataFrame(columns=["VIF Factor"])
for i in range(dfX.shape[1]):
    vif.loc[i] = variance_inflation_factor(dfX.values, i)
vif["features"] = dfX.columns

# %%
vif.sort_values(by="VIF Factor").reset_index(drop=True)
# Out:
#    VIF Factor           features
# 0    1.238083          scale(HP)
# 1    1.321772       scale(Speed)
# 2    1.428870     scale(Defense)
# 3    1.702689       scale(Spatk)
# 4    1.818655       scale(Spdef)
# 5   33.586286  scale(Generation)
# 6   33.981048          scale(Id)

# %% [markdown]
# - **VIF 결과 역시 Generation 과 id의 다중공산성이 높게 나온다.**

# %% [markdown]
# ## 3. 데이터 컬럼 조정

# %% [markdown]
# ### 3.1. 데이터 컬럼명 변경

# %% [markdown]
# - 모델을 정상적으로 돌리기 위해 컬럼명을 조정해 주겠다.

# %%
pm_data = pm_data.rename(columns={'#': 'Id', 'Type 1': 'Type1', 'Type 2': 'Type2', 'Sp. Atk': 'Spatk', 'Sp. Def': 'Spdef'})

# %%
pm_data.tail()
# Out:
#       Id                 Name    Type1  Type2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Spatk  Spdef  Speed  Generation  Legendary   Evol  Name_evol  Dual
# 795    100    150     50           6       True   True        1.0  True
# 796    160    110    110           6       True   True        2.0  True
# 797    150    130     70           6       True   True        1.0  True
# 798    170    130     80           6       True   True        2.0  True
# 799    130     90     70           6       True  False        0.0  True

# %% [markdown]
# ### 3.2. 데이터 컬럼타입 변경

# %% [markdown]
# - 메모리의 효율적인 사용과 모델 적용시 에러를 줄이기 위해 타입을 변경해준다.

# %%
pm_data["Type1"] = pm_data["Type1"].astype("category")

# %%
pm_data["Type2"] = pm_data["Type2"].astype("category")

# %%
pm_data["Generation"] = pm_data["Generation"].astype("category")

# %%
pm_data["Legendary"] = pm_data["Legendary"].astype("category")

# %%
pm_data["Name_evol"] = pm_data["Name_evol"].astype("category")

# %%
pm_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 16 columns):
# Id            800 non-null int64
# Name          800 non-null object
# Type1         800 non-null category
# Type2         800 non-null category
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Spatk         800 non-null int64
# Spdef         800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null category
# Legendary     800 non-null category
# Evol          800 non-null bool
# Name_evol     800 non-null category
# Dual          800 non-null bool
# dtypes: bool(2), category(5), int64(8), object(1)
# memory usage: 63.8+ KB

# %% [markdown]
# # 모델 돌려보기 START

# %% [markdown]
# ## `원형의 모델`

# %% [markdown]
# - **Dual 컬럼의 경우 Type2 와 상호작용에 의해서 생겨난 컬럼이므로 C(Type2):Dual 를 추가해주었다. **

# %%
model_pm = sm.OLS.from_formula("Attack ~ scale(Id) + C(Type1) + C(Type2) + scale(HP) + scale(Defense) + scale(Spatk) + scale(Spdef) + scale(Speed) + C(Generation) + Legendary + Dual + Evol + scale(Name_evol) + C(Type2):Dual + 0", data=pm_data)
result_pm = model_pm.fit()
print(result_pm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Attack   R-squared:                       0.624
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     18.46
# Date:                Fri, 11 Jan 2019   Prob (F-statistic):          7.29e-116
# Time:                        00:37:17   Log-Likelihood:                -3526.9
# No. Observations:                 800   AIC:                             7188.
# Df Residuals:                     733   BIC:                             7502.
# Df Model:                          66
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# C(Type1)[Bug]                        84.8439      9.086      9.338      0.000      67.007     102.681
# C(Type1)[Dark]                       86.9772     10.314      8.433      0.000      66.728     107.227
# C(Type1)[Dragon]                     87.1649     10.531      8.277      0.000      66.491     107.839
# C(Type1)[Electric]                   53.5760     10.573      5.067      0.000      32.819      74.333
# C(Type1)[Fairy]                      54.1434     17.713      3.057      0.002      19.370      88.917
# C(Type1)[Fighting]                   84.5996     12.693      6.665      0.000      59.680     109.519
# C(Type1)[Fire]                       75.3438     11.108      6.783      0.000      53.536      97.152
# C(Type1)[Flying]                     48.5947     18.170      2.674      0.008      12.923      84.267
# C(Type1)[Ghost]                      58.0799     10.307      5.635      0.000      37.844      78.315
# C(Type1)[Grass]                      77.7996     10.202      7.626      0.000      57.771      97.829
# C(Type1)[Ground]                     91.7372     10.477      8.756      0.000      71.169     112.305
# C(Type1)[Ice]                        74.8157     11.112      6.733      0.000      53.000      96.632
# C(Type1)[Normal]                     81.5894     10.380      7.860      0.000      61.211     101.968
# C(Type1)[Poison]                     72.5842     11.384      6.376      0.000      50.236      94.932
# C(Type1)[Psychic]                    80.1539     10.924      7.338      0.000      58.708     101.599
# C(Type1)[Rock]                       86.0871      9.888      8.706      0.000      66.675     105.499
# C(Type1)[Steel]                      84.1496     10.762      7.819      0.000      63.021     105.278
# C(Type1)[Water]                      72.7816      9.891      7.359      0.000      53.364      92.199
# C(Type2)[T.Dark]                     15.1893     10.184      1.491      0.136      -4.804      35.183
# C(Type2)[T.Dragon]                   29.7972     10.168      2.931      0.003       9.835      49.759
# C(Type2)[T.Electric]                 34.7091      9.047      3.836      0.000      16.948      52.470
# C(Type2)[T.Fairy]                    38.1025     16.955      2.247      0.025       4.816      71.389
# C(Type2)[T.Fighting]                 40.9934     11.282      3.633      0.000      18.844      63.143
# C(Type2)[T.Fire]                     26.0775      8.598      3.033      0.003       9.198      42.957
# C(Type2)[T.Flying]                   26.9919     22.972      1.175      0.240     -18.107      72.090
# C(Type2)[T.Ghost]                    42.9497     10.416      4.123      0.000      22.500      63.399
# C(Type2)[T.Grass]                    12.5275      7.862      1.593      0.111      -2.907      27.962
# C(Type2)[T.Ground]                   15.7629      9.736      1.619      0.106      -3.352      34.877
# C(Type2)[T.Ice]                      16.0219     10.809      1.482      0.139      -5.198      37.242
# C(Type2)[T.Normal]                   12.3594      7.580      1.631      0.103      -2.521      27.240
# C(Type2)[T.Poison]                   26.6337     10.150      2.624      0.009       6.707      46.560
# C(Type2)[T.Psychic]                  -8.4914      8.551     -0.993      0.321     -25.279       8.296
# C(Type2)[T.Rock]                     38.3563     10.109      3.794      0.000      18.509      58.203
# C(Type2)[T.Steel]                    11.7898     12.255      0.962      0.336     -12.270      35.849
# C(Type2)[T.Water]                    16.8116      7.220      2.328      0.020       2.637      30.986
# C(Generation)[T.2]                   -9.0969      4.172     -2.181      0.030     -17.287      -0.907
# C(Generation)[T.3]                  -13.8901      6.433     -2.159      0.031     -26.519      -1.261
# C(Generation)[T.4]                  -21.0374      9.319     -2.257      0.024     -39.332      -2.742
# C(Generation)[T.5]                  -28.9896     12.457     -2.327      0.020     -53.445      -4.535
# C(Generation)[T.6]                  -36.4739     15.272     -2.388      0.017     -66.456      -6.492
# Legendary[T.True]                     7.6927      3.474      2.214      0.027       0.872      14.513
# Dual[T.True]                         32.7295     13.919      2.351      0.019       5.404      60.055
# Evol[T.True]                          7.2160      5.089      1.418      0.157      -2.775      17.207
# C(Type2)[T.Dark]:Dual[T.True]        -8.9130     16.709     -0.533      0.594     -41.716      23.890
# C(Type2)[T.Dragon]:Dual[T.True]     -45.7320     17.062     -2.680      0.008     -79.229     -12.235
# C(Type2)[T.Electric]:Dual[T.True]   -67.2323     17.984     -3.738      0.000    -102.538     -31.926
# C(Type2)[T.Fairy]:Dual[T.True]      -70.6462     21.459     -3.292      0.001    -112.775     -28.518
# C(Type2)[T.Fighting]:Dual[T.True]   -39.4470     17.394     -2.268      0.024     -73.594      -5.300
# C(Type2)[T.Fire]:Dual[T.True]       -55.8785     16.735     -3.339      0.001     -88.733     -23.025
# C(Type2)[T.Flying]:Dual[T.True]     -48.2776     26.340     -1.833      0.067     -99.989       3.434
# C(Type2)[T.Ghost]:Dual[T.True]      -56.1508     17.567     -3.196      0.001     -90.638     -21.664
# C(Type2)[T.Grass]:Dual[T.True]      -24.6218     15.673     -1.571      0.117     -55.390       6.147
# C(Type2)[T.Ground]:Dual[T.True]     -27.0493     16.150     -1.675      0.094     -58.755       4.657
# C(Type2)[T.Ice]:Dual[T.True]        -35.3699     17.615     -2.008      0.045     -69.952      -0.788
# C(Type2)[T.Normal]:Dual[T.True]     -41.0510     18.599     -2.207      0.028     -77.564      -4.538
# C(Type2)[T.Poison]:Dual[T.True]     -43.9413     17.802     -2.468      0.014     -78.891      -8.991
# C(Type2)[T.Psychic]:Dual[T.True]    -25.6623     15.655     -1.639      0.102     -56.396       5.071
# C(Type2)[T.Rock]:Dual[T.True]       -56.1973     17.871     -3.145      0.002     -91.281     -21.114
# C(Type2)[T.Steel]:Dual[T.True]      -21.4844     18.249     -1.177      0.239     -57.310      14.341
# C(Type2)[T.Water]:Dual[T.True]      -44.0677     15.386     -2.864      0.004     -74.275     -13.861
# scale(Id)                            12.8373      5.189      2.474      0.014       2.649      23.025
# scale(HP)                             8.0467      0.914      8.803      0.000       6.252       9.841
# scale(Defense)                       10.0112      1.094      9.155      0.000       7.864      12.158
# scale(Spatk)                          7.1447      1.184      6.034      0.000       4.820       9.469
# scale(Spdef)                         -7.7448      1.076     -7.197      0.000      -9.858      -5.632
# scale(Speed)                          7.6338      0.969      7.880      0.000       5.732       9.536
# scale(Name_evol)                      3.6647      1.949      1.880      0.060      -0.162       7.491
# ==============================================================================
# Omnibus:                       23.371   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.199
# Skew:                           0.002   Prob(JB):                     2.81e-12
# Kurtosis:                       4.263   Cond. No.                         146.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - **다중공산성이 높게 나왔던 Id와 Generation 중 Id 를 제거시 con.Number 값이 소폭 줄어들었음을 확인할 수 있다.**

# %%
model_pm = sm.OLS.from_formula("Attack ~C(Type1) + C(Type2) + scale(HP) + scale(Defense) + scale(Spatk) + scale(Spdef) + scale(Speed) + C(Generation) + Legendary + Dual + Evol + scale(Name_evol) + C(Type2):Dual + 0", data=pm_data)
result = model_pm.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Attack   R-squared:                       0.621
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     18.52
# Date:                Fri, 11 Jan 2019   Prob (F-statistic):          3.02e-115
# Time:                        00:37:33   Log-Likelihood:                -3530.3
# No. Observations:                 800   AIC:                             7193.
# Df Residuals:                     734   BIC:                             7502.
# Df Model:                          65
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# C(Type1)[Bug]                        66.9679      5.526     12.118      0.000      56.119      77.817
# C(Type1)[Dark]                       70.7228      7.978      8.864      0.000      55.060      86.386
# C(Type1)[Dragon]                     70.8211      8.229      8.606      0.000      54.666      86.976
# C(Type1)[Electric]                   37.2327      8.283      4.495      0.000      20.971      53.495
# C(Type1)[Fairy]                      36.4050     16.253      2.240      0.025       4.498      68.312
# C(Type1)[Fighting]                   66.8900     10.518      6.359      0.000      46.240      87.540
# C(Type1)[Fire]                       55.8048      7.838      7.120      0.000      40.418      71.192
# C(Type1)[Flying]                     33.8660     17.227      1.966      0.050       0.046      67.686
# C(Type1)[Ghost]                      42.2349      8.104      5.212      0.000      26.326      58.144
# C(Type1)[Grass]                      59.9201      7.225      8.293      0.000      45.735      74.105
# C(Type1)[Ground]                     75.3271      8.137      9.257      0.000      59.352      91.303
# C(Type1)[Ice]                        59.3071      9.207      6.442      0.000      41.232      77.382
# C(Type1)[Normal]                     63.3496      7.332      8.640      0.000      48.956      77.743
# C(Type1)[Poison]                     54.5343      8.768      6.220      0.000      37.321      71.748
# C(Type1)[Psychic]                    62.0255      8.129      7.630      0.000      46.067      77.985
# C(Type1)[Rock]                       69.7825      7.396      9.435      0.000      55.262      84.303
# C(Type1)[Steel]                      67.0916      8.292      8.091      0.000      50.813      83.370
# C(Type1)[Water]                      55.2839      6.937      7.969      0.000      41.665      68.903
# C(Type2)[T.Dark]                     13.2245     10.188      1.298      0.195      -6.777      33.226
# C(Type2)[T.Dragon]                   31.6113     10.177      3.106      0.002      11.632      51.590
# C(Type2)[T.Electric]                 33.3279      9.061      3.678      0.000      15.539      51.117
# C(Type2)[T.Fairy]                    37.8589     17.014      2.225      0.026       4.457      71.260
# C(Type2)[T.Fighting]                 41.2793     11.321      3.646      0.000      19.054      63.505
# C(Type2)[T.Fire]                     27.0443      8.619      3.138      0.002      10.123      43.965
# C(Type2)[T.Flying]                   25.9749     23.048      1.127      0.260     -19.273      71.223
# C(Type2)[T.Ghost]                    42.4588     10.451      4.063      0.000      21.942      62.976
# C(Type2)[T.Grass]                    11.2601      7.873      1.430      0.153      -4.195      26.716
# C(Type2)[T.Ground]                   14.6825      9.760      1.504      0.133      -4.479      33.844
# C(Type2)[T.Ice]                      15.9843     10.847      1.474      0.141      -5.310      37.278
# C(Type2)[T.Normal]                   13.0743      7.600      1.720      0.086      -1.847      27.995
# C(Type2)[T.Poison]                   26.5195     10.185      2.604      0.009       6.524      46.515
# C(Type2)[T.Psychic]                  -7.3825      8.569     -0.862      0.389     -24.205       9.440
# C(Type2)[T.Rock]                     35.8206     10.092      3.549      0.000      16.007      55.634
# C(Type2)[T.Steel]                    12.2584     12.296      0.997      0.319     -11.882      36.399
# C(Type2)[T.Water]                    16.6693      7.245      2.301      0.022       2.446      30.892
# C(Generation)[T.2]                   -1.3919      2.785     -0.500      0.617      -6.859       4.075
# C(Generation)[T.3]                    0.7214      2.557      0.282      0.778      -4.299       5.742
# C(Generation)[T.4]                    1.0250      2.711      0.378      0.706      -4.298       6.348
# C(Generation)[T.5]                    1.1803      2.544      0.464      0.643      -3.814       6.174
# C(Generation)[T.6]                    0.4285      3.282      0.131      0.896      -6.014       6.871
# Legendary[T.True]                    10.0206      3.356      2.986      0.003       3.432      16.609
# Dual[T.True]                         33.8700     13.960      2.426      0.015       6.464      61.275
# Evol[T.True]                          7.4432      5.106      1.458      0.145      -2.581      17.467
# C(Type2)[T.Dark]:Dual[T.True]        -8.1850     16.765     -0.488      0.626     -41.097      24.727
# C(Type2)[T.Dragon]:Dual[T.True]     -49.0726     17.068     -2.875      0.004     -82.581     -15.565
# C(Type2)[T.Electric]:Dual[T.True]   -66.6447     18.045     -3.693      0.000    -102.071     -31.219
# C(Type2)[T.Fairy]:Dual[T.True]      -72.2391     21.524     -3.356      0.001    -114.495     -29.983
# C(Type2)[T.Fighting]:Dual[T.True]   -40.4989     17.449     -2.321      0.021     -74.755      -6.243
# C(Type2)[T.Fire]:Dual[T.True]       -57.5667     16.779     -3.431      0.001     -90.508     -24.626
# C(Type2)[T.Flying]:Dual[T.True]     -48.5978     26.432     -1.839      0.066    -100.489       3.293
# C(Type2)[T.Ghost]:Dual[T.True]      -56.5626     17.627     -3.209      0.001     -91.168     -21.957
# C(Type2)[T.Grass]:Dual[T.True]      -24.5364     15.727     -1.560      0.119     -55.412       6.339
# C(Type2)[T.Ground]:Dual[T.True]     -27.8705     16.203     -1.720      0.086     -59.680       3.939
# C(Type2)[T.Ice]:Dual[T.True]        -35.7585     17.676     -2.023      0.043     -70.459      -1.058
# C(Type2)[T.Normal]:Dual[T.True]     -42.2430     18.657     -2.264      0.024     -78.870      -5.616
# C(Type2)[T.Poison]:Dual[T.True]     -46.4107     17.836     -2.602      0.009     -81.427     -11.394
# C(Type2)[T.Psychic]:Dual[T.True]    -27.3110     15.695     -1.740      0.082     -58.123       3.501
# C(Type2)[T.Rock]:Dual[T.True]       -54.6110     17.921     -3.047      0.002     -89.794     -19.428
# C(Type2)[T.Steel]:Dual[T.True]      -22.7931     18.304     -1.245      0.213     -58.728      13.142
# C(Type2)[T.Water]:Dual[T.True]      -44.1289     15.440     -2.858      0.004     -74.441     -13.817
# scale(HP)                             8.1534      0.916      8.898      0.000       6.355       9.952
# scale(Defense)                       10.2515      1.093      9.379      0.000       8.106      12.397
# scale(Spatk)                          7.3380      1.186      6.189      0.000       5.011       9.666
# scale(Spdef)                         -7.6050      1.078     -7.052      0.000      -9.722      -5.488
# scale(Speed)                          7.6989      0.972      7.923      0.000       5.791       9.607
# scale(Name_evol)                      3.4937      1.955      1.787      0.074      -0.344       7.331
# ==============================================================================
# Omnibus:                       22.070   Durbin-Watson:                   1.587
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.724
# Skew:                           0.078   Prob(JB):                     7.14e-11
# Kurtosis:                       4.174   Cond. No.                         144.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 4. 아웃라이어 파악하기

# %% [markdown]
# - 플로우 : Outlier 파악 -> Cooks Distance 파악

# %% [markdown]
# ### 4.1. statsmodels를 이용한 표준화 잔차 계산

# %%
plt.figure(figsize=(10, 2))
plt.stem(result.resid)
plt.title("resid")
plt.show()

# %%
plt.figure(figsize=(10, 2))
plt.stem(result.resid_pearson)
plt.axhline(3, c="g", ls="--")
plt.axhline(-3, c="g", ls="--")
plt.title("resid_pearson")
plt.show()

# %%
len(result.resid_pearson)
# Out:
# 800

# %%
idx_resid1 = result.resid_pearson > 2.5
pm_data_resid1 = pm_data.iloc[idx_resid1 == True, :]
pm_data_resid1.index
# Out:
# Int64Index([19, 147, 232, 235, 387, 429, 454, 650], dtype='int64')

# %%
idx_resid2 = result.resid_pearson < -2.5
pm_data_resid2 = pm_data.iloc[idx_resid2 == True, :]
pm_data_resid2.index
# Out:
# Int64Index([103, 121, 261, 616, 699, 713, 714], dtype='int64')

# %%
outlier = []
outlier.extend(pm_data_resid1.index)
outlier.extend(pm_data_resid2.index)
outlier = list(set(outlier))
outlier
# Out:
# [387, 261, 454, 103, 232, 616, 650, 235, 713, 429, 714, 19, 147, 121, 699]

# %%
idx_surv = list(set(range(len(pm_data))).difference(outlier))

# %%
pm_data_del_out = pm_data.iloc[idx_surv, :].reset_index(drop=True)

# %%
len(pm_data_del_out)
# Out:
# 785

# %%
model_outlier = sm.OLS.from_formula("Attack ~ C(Type1) + C(Type2) + scale(HP) + scale(Defense) + scale(Spatk) + scale(Spdef) + scale(Speed) + C(Generation) + Legendary + Dual + Evol + scale(Name_evol) + C(Type2):Dual + 0", data=pm_data_del_out)
result_outlier = model_outlier.fit()
print(result_outlier.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Attack   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     23.30
# Date:                Fri, 11 Jan 2019   Prob (F-statistic):          1.44e-136
# Time:                        00:37:52   Log-Likelihood:                -3376.7
# No. Observations:                 785   AIC:                             6885.
# Df Residuals:                     719   BIC:                             7193.
# Df Model:                          65
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# C(Type1)[Bug]                        67.8981      4.952     13.712      0.000      58.177      77.619
# C(Type1)[Dark]                       74.1098      7.175     10.329      0.000      60.024      88.196
# C(Type1)[Dragon]                     74.6205      7.398     10.087      0.000      60.097      89.144
# C(Type1)[Electric]                   43.7433      7.459      5.864      0.000      29.098      58.388
# C(Type1)[Fairy]                      40.0039     14.566      2.746      0.006      11.406      68.601
# C(Type1)[Fighting]                   72.6114      9.457      7.678      0.000      54.045      91.178
# C(Type1)[Fire]                       61.4737      7.131      8.621      0.000      47.474      75.473
# C(Type1)[Flying]                     39.7573     15.440      2.575      0.010       9.445      70.070
# C(Type1)[Ghost]                      46.4317      7.278      6.379      0.000      32.143      60.721
# C(Type1)[Grass]                      63.6920      6.499      9.800      0.000      50.932      76.452
# C(Type1)[Ground]                     78.4617      7.310     10.733      0.000      64.109      92.814
# C(Type1)[Ice]                        62.2431      8.262      7.534      0.000      46.022      78.464
# C(Type1)[Normal]                     65.9723      6.589     10.013      0.000      53.036      78.908
# C(Type1)[Poison]                     57.6189      7.874      7.318      0.000      42.160      73.077
# C(Type1)[Psychic]                    65.8863      7.313      9.009      0.000      51.528      80.244
# C(Type1)[Rock]                       75.8227      6.676     11.357      0.000      62.716      88.930
# C(Type1)[Steel]                      75.2751      7.548      9.972      0.000      60.456      90.095
# C(Type1)[Water]                      60.8853      6.258      9.729      0.000      48.599      73.171
# C(Type2)[T.Dark]                     11.0388      9.156      1.206      0.228      -6.937      29.015
# C(Type2)[T.Dragon]                   27.7391      9.141      3.035      0.002       9.794      45.685
# C(Type2)[T.Electric]                 27.8139      8.145      3.415      0.001      11.823      43.805
# C(Type2)[T.Fairy]                    33.6584     15.246      2.208      0.028       3.727      63.590
# C(Type2)[T.Fighting]                 34.3693     10.174      3.378      0.001      14.395      54.343
# C(Type2)[T.Fire]                     19.4123      7.846      2.474      0.014       4.009      34.816
# C(Type2)[T.Flying]                   20.9135     20.665      1.012      0.312     -19.658      61.485
# C(Type2)[T.Ghost]                    33.2490      9.627      3.454      0.001      14.348      52.150
# C(Type2)[T.Grass]                     8.0061      7.090      1.129      0.259      -5.914      21.926
# C(Type2)[T.Ground]                   11.8378      8.765      1.351      0.177      -5.371      29.046
# C(Type2)[T.Ice]                      13.0110      9.742      1.335      0.182      -6.116      32.138
# C(Type2)[T.Normal]                   11.8576      6.843      1.733      0.084      -1.578      25.293
# C(Type2)[T.Poison]                   22.9045      9.145      2.505      0.012       4.951      40.858
# C(Type2)[T.Psychic]                 -12.7993      7.722     -1.658      0.098     -27.959       2.360
# C(Type2)[T.Rock]                     23.3262      9.371      2.489      0.013       4.929      41.724
# C(Type2)[T.Steel]                     4.9264     11.088      0.444      0.657     -16.843      26.695
# C(Type2)[T.Water]                    11.3777      6.549      1.737      0.083      -1.479      24.234
# C(Generation)[T.2]                   -2.6180      2.531     -1.035      0.301      -7.586       2.350
# C(Generation)[T.3]                   -0.9066      2.307     -0.393      0.694      -5.436       3.623
# C(Generation)[T.4]                   -0.3558      2.455     -0.145      0.885      -5.175       4.463
# C(Generation)[T.5]                    1.9367      2.316      0.836      0.403      -2.610       6.483
# C(Generation)[T.6]                   -0.7842      2.954     -0.265      0.791      -6.584       5.016
# Legendary[T.True]                     8.9042      3.056      2.913      0.004       2.904      14.905
# Dual[T.True]                         30.8275     12.526      2.461      0.014       6.236      55.419
# Evol[T.True]                          8.4631      4.613      1.835      0.067      -0.594      17.520
# C(Type2)[T.Dark]:Dual[T.True]        -7.0009     15.047     -0.465      0.642     -36.541      22.540
# C(Type2)[T.Dragon]:Dual[T.True]     -46.7405     15.309     -3.053      0.002     -76.797     -16.684
# C(Type2)[T.Electric]:Dual[T.True]   -63.5453     16.204     -3.922      0.000     -95.358     -31.733
# C(Type2)[T.Fairy]:Dual[T.True]      -68.7773     19.287     -3.566      0.000    -106.643     -30.911
# C(Type2)[T.Fighting]:Dual[T.True]   -29.2436     15.727     -1.860      0.063     -60.119       1.632
# C(Type2)[T.Fire]:Dual[T.True]       -49.9506     15.119     -3.304      0.001     -79.634     -20.267
# C(Type2)[T.Flying]:Dual[T.True]     -43.7062     23.698     -1.844      0.066     -90.231       2.819
# C(Type2)[T.Ghost]:Dual[T.True]      -48.3030     15.959     -3.027      0.003     -79.634     -16.972
# C(Type2)[T.Grass]:Dual[T.True]      -20.9716     14.132     -1.484      0.138     -48.716       6.772
# C(Type2)[T.Ground]:Dual[T.True]     -25.0946     14.565     -1.723      0.085     -53.689       3.499
# C(Type2)[T.Ice]:Dual[T.True]        -35.1657     15.862     -2.217      0.027     -66.308      -4.024
# C(Type2)[T.Normal]:Dual[T.True]     -42.7839     16.739     -2.556      0.011     -75.647      -9.921
# C(Type2)[T.Poison]:Dual[T.True]     -44.3222     16.009     -2.769      0.006     -75.753     -12.891
# C(Type2)[T.Psychic]:Dual[T.True]    -21.1314     14.116     -1.497      0.135     -48.846       6.583
# C(Type2)[T.Rock]:Dual[T.True]       -43.6199     16.244     -2.685      0.007     -75.512     -11.728
# C(Type2)[T.Steel]:Dual[T.True]      -18.4391     16.451     -1.121      0.263     -50.736      13.858
# C(Type2)[T.Water]:Dual[T.True]      -39.1823     13.854     -2.828      0.005     -66.382     -11.983
# scale(HP)                             9.5901      0.855     11.211      0.000       7.911      11.269
# scale(Defense)                        9.7370      1.021      9.538      0.000       7.733      11.741
# scale(Spatk)                          6.9495      1.092      6.366      0.000       4.806       9.093
# scale(Spdef)                         -7.2090      0.990     -7.283      0.000      -9.152      -5.266
# scale(Speed)                          7.2016      0.878      8.200      0.000       5.477       8.926
# scale(Name_evol)                      2.5809      1.753      1.472      0.141      -0.860       6.022
# ==============================================================================
# Omnibus:                       10.278   Durbin-Watson:                   1.630
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.303
# Skew:                           0.275   Prob(JB):                      0.00579
# Kurtosis:                       3.109   Cond. No.                         144.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 4.2. Cook's Distance

# %% [markdown]
# - Cook's Distance 를 기준으로 아웃라이어와 레버리지를 동시에 고려한 데이터 파악

# %%
cook_influence_pm = result.get_influence()
cooks_d2, pvals = cook_influence_pm.cooks_distance
fox_cr = 4 / (len(pm_data_del_out) - 2)
idx = np.where(cooks_d2 > fox_cr)[0]

# %% [markdown]
# - Cook's Distance 를 기준으로 뽑아낸 row(아웃라이어+레버리지)를 제거

# %%
idx_surv = list(set(range(len(pm_data_del_out))).difference(idx))

# %%
pm_data_del_cook = pm_data_del_out.iloc[idx_surv, :].reset_index(drop=True)

# %%
model_cooks = sm.OLS.from_formula("Attack ~ C(Type1) + C(Type2) + scale(HP) + scale(Defense) + scale(Spatk) + scale(Spdef) + scale(Speed) + C(Generation) + Legendary + Dual + Evol + scale(Name_evol) + C(Type2):Dual + 0", data=pm_data_del_cook)
result_cooks = model_cooks.fit()
print(result_cooks.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Attack   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     21.67
# Date:                Fri, 11 Jan 2019   Prob (F-statistic):          4.60e-125
# Time:                        00:38:08   Log-Likelihood:                -3150.0
# No. Observations:                 734   AIC:                             6432.
# Df Residuals:                     668   BIC:                             6736.
# Df Model:                          65
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# C(Type1)[Bug]                        67.8117      4.945     13.714      0.000      58.103      77.521
# C(Type1)[Dark]                       74.3252      7.238     10.269      0.000      60.114      88.536
# C(Type1)[Dragon]                     78.4233      7.612     10.302      0.000      63.476      93.370
# C(Type1)[Electric]                   44.6352      7.635      5.846      0.000      29.643      59.627
# C(Type1)[Fairy]                      41.1042     14.540      2.827      0.005      12.555      69.653
# C(Type1)[Fighting]                   72.5755      9.442      7.686      0.000      54.036      91.115
# C(Type1)[Fire]                       61.6299      7.291      8.453      0.000      47.314      75.945
# C(Type1)[Flying]                     36.6959     15.526      2.364      0.018       6.211      67.181
# C(Type1)[Ghost]                      46.3778      7.278      6.372      0.000      32.088      60.668
# C(Type1)[Grass]                      62.7480      6.517      9.628      0.000      49.951      75.545
# C(Type1)[Ground]                     78.2306      7.314     10.696      0.000      63.870      92.591
# C(Type1)[Ice]                        62.5546      8.614      7.262      0.000      45.642      79.467
# C(Type1)[Normal]                     68.1455      6.656     10.238      0.000      55.077      81.214
# C(Type1)[Poison]                     56.4162      7.880      7.159      0.000      40.943      71.889
# C(Type1)[Psychic]                    66.0671      7.323      9.022      0.000      51.688      80.446
# C(Type1)[Rock]                       71.1722      6.895     10.323      0.000      57.634      84.710
# C(Type1)[Steel]                      74.4558      7.666      9.712      0.000      59.403      89.509
# C(Type1)[Water]                      59.6671      6.297      9.475      0.000      47.302      72.032
# C(Type2)[T.Dark]                     11.1170      9.184      1.210      0.227      -6.916      29.150
# C(Type2)[T.Dragon]                   23.6036      9.269      2.546      0.011       5.403      41.804
# C(Type2)[T.Electric]                 28.0148      8.342      3.358      0.001      11.635      44.394
# C(Type2)[T.Fairy]                    31.5456     15.201      2.075      0.038       1.699      61.393
# C(Type2)[T.Fighting]                 35.3056     10.195      3.463      0.001      15.288      55.323
# C(Type2)[T.Fire]                     20.3870      8.055      2.531      0.012       4.571      36.203
# C(Type2)[T.Flying]                   25.0133     20.711      1.208      0.228     -15.654      65.680
# C(Type2)[T.Ghost]                    28.1487     10.111      2.784      0.006       8.296      48.002
# C(Type2)[T.Grass]                     8.8508      7.112      1.244      0.214      -5.114      22.816
# C(Type2)[T.Ground]                   12.0430      8.747      1.377      0.169      -5.133      29.219
# C(Type2)[T.Ice]                      15.9850     10.283      1.555      0.121      -4.205      36.175
# C(Type2)[T.Normal]                   10.8730      6.951      1.564      0.118      -2.775      24.521
# C(Type2)[T.Poison]                   24.2830      9.127      2.660      0.008       6.361      42.205
# C(Type2)[T.Psychic]                 -14.3050      7.791     -1.836      0.067     -29.603       0.993
# C(Type2)[T.Rock]                     33.0528      9.802      3.372      0.001      13.806      52.300
# C(Type2)[T.Steel]                     3.7053     11.826      0.313      0.754     -19.515      26.925
# C(Type2)[T.Water]                    12.8083      6.607      1.939      0.053      -0.164      25.781
# C(Generation)[T.2]                   -1.9951      2.617     -0.762      0.446      -7.133       3.143
# C(Generation)[T.3]                   -0.7517      2.357     -0.319      0.750      -5.380       3.876
# C(Generation)[T.4]                   -0.9013      2.549     -0.354      0.724      -5.907       4.104
# C(Generation)[T.5]                    1.4594      2.378      0.614      0.540      -3.210       6.129
# C(Generation)[T.6]                    1.2809      3.121      0.410      0.682      -4.848       7.409
# Legendary[T.True]                    10.1245      3.135      3.229      0.001       3.968      16.281
# Dual[T.True]                         34.1749     12.513      2.731      0.006       9.605      58.745
# Evol[T.True]                          6.8658      4.683      1.466      0.143      -2.330      16.061
# C(Type2)[T.Dark]:Dual[T.True]        -9.6509     15.087     -0.640      0.523     -39.275      19.974
# C(Type2)[T.Dragon]:Dual[T.True]     -44.9728     15.503     -2.901      0.004     -75.413     -14.532
# C(Type2)[T.Electric]:Dual[T.True]   -66.8501     16.280     -4.106      0.000     -98.817     -34.883
# C(Type2)[T.Fairy]:Dual[T.True]      -70.0270     19.233     -3.641      0.000    -107.792     -32.262
# C(Type2)[T.Fighting]:Dual[T.True]   -31.7902     15.781     -2.014      0.044     -62.777      -0.804
# C(Type2)[T.Fire]:Dual[T.True]       -54.1625     15.255     -3.550      0.000     -84.116     -24.209
# C(Type2)[T.Flying]:Dual[T.True]     -52.0634     23.742     -2.193      0.029     -98.681      -5.446
# C(Type2)[T.Ghost]:Dual[T.True]      -46.1872     16.227     -2.846      0.005     -78.050     -14.324
# C(Type2)[T.Grass]:Dual[T.True]      -24.8723     14.134     -1.760      0.079     -52.624       2.880
# C(Type2)[T.Ground]:Dual[T.True]     -24.8872     14.539     -1.712      0.087     -53.435       3.660
# C(Type2)[T.Ice]:Dual[T.True]        -39.6129     16.268     -2.435      0.015     -71.556      -7.669
# C(Type2)[T.Normal]:Dual[T.True]     -51.0882     17.597     -2.903      0.004     -85.640     -16.537
# C(Type2)[T.Poison]:Dual[T.True]     -48.8721     16.032     -3.048      0.002     -80.350     -17.394
# C(Type2)[T.Psychic]:Dual[T.True]    -22.6684     14.135     -1.604      0.109     -50.424       5.087
# C(Type2)[T.Rock]:Dual[T.True]       -53.4877     16.673     -3.208      0.001     -86.225     -20.750
# C(Type2)[T.Steel]:Dual[T.True]      -19.4302     16.990     -1.144      0.253     -52.790      13.930
# C(Type2)[T.Water]:Dual[T.True]      -43.5958     13.992     -3.116      0.002     -71.068     -16.123
# scale(HP)                             9.1081      0.873     10.435      0.000       7.394      10.822
# scale(Defense)                        9.8788      1.030      9.591      0.000       7.856      11.901
# scale(Spatk)                          6.8755      1.132      6.075      0.000       4.653       9.098
# scale(Spdef)                         -7.1280      1.020     -6.985      0.000      -9.132      -5.124
# scale(Speed)                          7.3563      0.910      8.082      0.000       5.569       9.144
# scale(Name_evol)                      2.5209      1.797      1.403      0.161      -1.007       6.049
# ==============================================================================
# Omnibus:                       16.434   Durbin-Watson:                   1.636
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.915
# Skew:                           0.363   Prob(JB):                     0.000212
# Kurtosis:                       3.165   Cond. No.                         141.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - R 스퀘어 값에는 크게 차이가 나지 않았다.

# %% [markdown]
# # Final K-Fold 교차검증

# %% [markdown]
# - 표본 내에서 성능검증을 하기위하여 K-Fold 교차 검증을 시행해 보았다.

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(pm_data_del_cook)):
    df_train = pm_data_del_cook.iloc[idx_train]
    df_test = pm_data_del_cook.iloc[idx_test]
    
    model_cooks = sm.OLS.from_formula("Attack ~ C(Type1) + C(Type2) + scale(HP) + scale(Defense) + scale(Spatk) + scale(Spdef) + scale(Speed) + C(Generation) + Legendary + Dual + Evol + scale(Name_evol) + C(Type2):Dual + 0", data=pm_data_del_cook)
    result_cooks = model_cooks.fit()
    
    pred = result_cooks.predict(df_test)
    rss = ((df_test.Attack - pred) ** 2).sum()
    tss = ((df_test.Attack - df_test.Attack.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result_cooks.rsquared, rsquared))
# Out:
# 학습 R2 = 0.67833078, 검증 R2 = 0.72518069
# 학습 R2 = 0.67833078, 검증 R2 = 0.70868330
# 학습 R2 = 0.67833078, 검증 R2 = 0.66548999
# 학습 R2 = 0.67833078, 검증 R2 = 0.67939932
# 학습 R2 = 0.67833078, 검증 R2 = 0.57985263

# %%
scores.mean()
# Out:
# 0.6717211878388318

# %% [markdown]
# - **학습 R2 보다 잘 나올때도 있고 안나올때도 있었다. 평균값은 학습 R2와 대체로 비슷함을 확인할 수 있으므로 과최적화는 피하였다.**

# %% [markdown]
# - **TODO 및 아쉬운점**
#     + Type1 과 Type2 컬럼에 대해서 더 세분화해서 데이터를 뽑아 내었으면 좋았을것 같다.
#         + 예를 들어 Type의 속성들에 대해서 하나하나 카테고리화 시킨다던지 조금 더 분석을 하면 좋은 결과가 나왔을 수도 있을것이다.
#     + 수치데이터와 Lengendary 데이터 간의 관계를 더 명확히 분석했으면 더 좋은 결과가 나왔을 것 같다.
#     + 모델 분석후 p value가 높게나온 유의하지 않은 카테고리 데이터들에 대해서 조치를 취할 수 있는 방법을 강구해야겠다.
#     + 각 컬럼들에 대한 계수 값들에 대한 검증을 거쳐야했는데 하지 못하였다.
