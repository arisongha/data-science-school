# %%
crime_anal_police = pd.read_csv('crime_in_seoul_2015.csv', thousands=',', encoding='euc-kr')
crime_anal_police = pd.DataFrame(crime_anal_police)
crime_anal_police.head()
# Out:
#       범죄명           장소   발생건수
# 0      살인  아파트, 연립 다세대     20
# 1      살인         단독주택     39
# 2      살인           노상     37
# 3      살인           상점      1
# 4      살인    숙박업소, 목욕탕      3
# 5      살인      유흥 접객업소      5
# 6      살인          사무실      3
# 7      살인       역, 대합실      0
# 8      살인         교통수단      0
# 9      살인         유원지       4
# 10     살인           학교      1
# 11     살인         금융기관      0
# 12     살인           기타     50
# 13     강도  아파트, 연립 다세대     20
# 14     강도         단독주택     23
# 15     강도           노상     70
# 16     강도           상점     34
# 17     강도    숙박업소, 목욕탕     15
# 18     강도      유흥 접객업소     14
# 19     강도          사무실      8
# 20     강도       역, 대합실      0
# 21     강도         교통수단      3
# 22     강도         유원지       1
# 23     강도           학교      0
# 24     강도         금융기관      3
# 25     강도           기타     85
# 26  강간.추행  아파트, 연립 다세대    283
# 27  강간.추행         단독주택    346
# 28  강간.추행           노상    924
# 29  강간.추행           상점     73
# ...
